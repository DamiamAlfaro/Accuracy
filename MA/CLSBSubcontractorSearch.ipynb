# %% [markdown]
# <a href="https://colab.research.google.com/github/DamiamAlfaro/Sonder/blob/main/MA/CLSBSubcontractorSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-df93fa45-201b-4681-bf80-932100689298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df93fa45-201b-4681-bf80-932100689298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('CaliforniaSubcontractors042824.xlsx',names=None,header=None)
df
# Out:
#                   0            1             2                         3   \
# 0      LicenseNumber  LastUpdated  BusinessType              BusinessName
# 1             933700   09/11/2023   Corporation   CAL PASO SOLAR ELECTRIC
# 2             315246   08/09/2023    Sole Owner        SOLECTRIC ELECTRIC
# 3             967334   03/25/2024    Sole Owner           PULIDO CONCRETE
# 4            1005871   04/23/2024    Sole Owner  AZTEC DRYWALL SPECIALIST
# ...              ...          ...           ...                       ...
# 47525        1081743   08/22/2023   Corporation           DG ELECTRIC INC
# 47526        1097803   02/02/2024   Corporation          M Z ELECTRIC INC
# 47527        1097823   12/31/2022    Sole Owner         J T M WOODWORKING
# 47528        1097827   12/31/2022    Sole Owner            KONZMANN KEVIN
# 47529         668065   02/23/2024    Sole Owner              COHEN SHLOMO
#
#                               4              5      6      7   \
# ...

# %%
xls = pd.ExcelFile('CaliforniaSubcontractors042824.xlsx')

# %%
xls.sheet_names
# Out:
# ['C2-C12',
#  'C13-C28',
#  'C29-C42',
#  'C43-C55',
#  'C57-D16',
#  'D21-D39',
#  'D40-D62',
#  'D63-D65',
#  'Asbestos-HazardousRemoval',
#  'Suggestion1',
#  'Suggestion2']

# %%
df = pd.read_excel('CaliforniaSubcontractors042824.xlsx',sheet_name=0)
df
# Out:
#        LicenseNumber LastUpdated BusinessType              BusinessName  \
# 0             933700  09/11/2023  Corporation   CAL PASO SOLAR ELECTRIC
# 1             315246  08/09/2023   Sole Owner        SOLECTRIC ELECTRIC
# 2             967334  03/25/2024   Sole Owner           PULIDO CONCRETE
# 3            1005871  04/23/2024   Sole Owner  AZTEC DRYWALL SPECIALIST
# 4             754942  05/18/2023   Sole Owner                  WALLTECH
# ...              ...         ...          ...                       ...
# 47524        1081743  08/22/2023  Corporation           DG ELECTRIC INC
# 47525        1097803  02/02/2024  Corporation          M Z ELECTRIC INC
# 47526        1097823  12/31/2022   Sole Owner         J T M WOODWORKING
# 47527        1097827  12/31/2022   Sole Owner            KONZMANN KEVIN
# 47528         668065  02/23/2024   Sole Owner              COHEN SHLOMO
#
#                          Address           City State    Zip           County  \
# ...

# %%
filtered_rows = df[df.iloc[:, 12].str.contains('C-5', na=False) & df.iloc[:, 8].str.contains('Ventura', na=False)]
filtered_rows
# Out:
#        LicenseNumber LastUpdated BusinessType  \
# 4159          792572  02/27/2024  Corporation
# 8672          917459  02/05/2024   Sole Owner
# 9465         1109986  09/13/2023  Corporation
# 10429         830809  02/02/2024   Sole Owner
# 11026         775540  02/20/2024   Sole Owner
# 12715        1104909  05/18/2023   Sole Owner
# 12975         800362  10/11/2023   Sole Owner
# 13194         981871  09/26/2023   Sole Owner
# 17149        1073824  01/29/2024  Corporation
# 17438         974938  07/13/2023   Sole Owner
# 17487        1114664  01/08/2024   Sole Owner
# 18574        1020614  07/07/2023   Sole Owner
# 23541         999013  06/01/2023  Corporation
# 27554        1102821  01/24/2024  Corporation
# 28685         948113  11/17/2023   Sole Owner
# 29670         963140  04/22/2024  Corporation
# 32265         842900  12/31/2022  Partnership
# 32428         869442  11/21/2023   Sole Owner
# 32981        1101659  03/28/2024  Corporation
# ...
